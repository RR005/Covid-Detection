# %%
import pandas as pd
import numpy as np

import os
import cv2

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from PIL import Image
import math
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array
# Out:
# Using TensorFlow backend.

# %%
img_dir = "F:\study\corona\covid-chestxray-dataset-master\coronahack-chest-xraydataset\Coronahack-Chest-XRay-Dataset\Coronahack-Chest-XRay-Dataset\train"
img_dir = "F:/study/corona/covid-chestxray-dataset-master/coronahack-chest-xraydataset/Coronahack-Chest-XRay-Dataset/Coronahack-Chest-XRay-Dataset/train"

# %%
img_dir2 = "F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images"

# %%
tr_csv = pd.read_csv("F:\study\corona\covid-chestxray-dataset-master\coronahack-chest-xraydataset\Chest_xray_Corona_Metadata.csv")

# %%
tes_csv = pd.read_csv("F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\metadata2.csv")

# %%
tr_csv.head()
# Out:
#    Unnamed: 0   X_ray_image_name   Label Dataset_type Label_2_Virus_category  \
# 0           0  IM-0128-0001.jpeg  Normal        TRAIN                    NaN
# 1           1  IM-0127-0001.jpeg  Normal        TRAIN                    NaN
# 2           2  IM-0125-0001.jpeg  Normal        TRAIN                    NaN
# 3           3  IM-0122-0001.jpeg  Normal        TRAIN                    NaN
# 4           4  IM-0119-0001.jpeg  Normal        TRAIN                    NaN
#
#   Label_1_Virus_category
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
tes_csv.head()
# Out:
#    id                                           filename  patientid  offset  \
# 0   1  auntminnie-a-2020_01_28_23_51_6665_2020_01_28_...          2     0.0
# 1   2  auntminnie-b-2020_01_28_23_51_6665_2020_01_28_...          2     3.0
# 2   3  auntminnie-c-2020_01_28_23_51_6665_2020_01_28_...          2     5.0
# 3   4  auntminnie-d-2020_01_28_23_51_6665_2020_01_28_...          2     6.0
# 4   5                              nejmc2001573_f1a.jpeg          4     0.0
#
#   sex   age   finding survival  temperature  leukocyte count  ...  \
# 0   M  65.0  COVID-19        Y          NaN              NaN  ...
# 1   M  65.0  COVID-19        Y          NaN              NaN  ...
# 2   M  65.0  COVID-19        Y          NaN              NaN  ...
# 3   M  65.0  COVID-19        Y          NaN              NaN  ...
# 4   F  52.0  COVID-19      NaN          NaN              NaN  ...
#
#    pO2 saturation  view  modality              date                   doi  \
# ...

# %%
tr_csv['Label'].unique()
# Out:
# array(['Normal', 'Pnemonia'], dtype=object)

# %%
i=0
normal = []
for idex,row in tr_csv.iterrows():
    if row['Label']=='Normal' and i<500:
        i+=1  
        data_path = os.path.join(img_dir,row['X_ray_image_name'])
        img = cv2.imread(data_path)
        img = cv2.resize(img,(256,256),interpolation = cv2.INTER_AREA)  
        normal.append(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-15-72117c92d481> in <module>
#       6         data_path = os.path.join(img_dir,row['X_ray_image_name'])
#       7         img = cv2.imread(data_path)
# ----> 8         img = cv2.resize(img,(256,256),interpolation = cv2.INTER_AREA)
#       9         normal.append(img)
#
# error: OpenCV(4.2.0) C:\projects\opencv-python\opencv\modules\imgproc\src\resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
normal
# Out:
# []

# %%
covid = []
for idex,row in tes_csv.iterrows():
    if row['finding']=='COVID-19': 
        data_path = os.path.join(img_dir2,row['filename'])
        print(data_path)
        img = cv2.imread(data_path)
        img = cv2.resize(img,(256,256))  
        covid.append(img)
# Out:
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\nejmc2001573_f1a.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\nejmc2001573_f1b.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\lancet-case2a.jpg
# ...

# %%
covid[0].shape
# Out:
# (256, 256, 3)

# %%
non_covid = []
for idex,row in tes_csv.iterrows():
    if row['finding']!='COVID-19': 
        data_path = os.path.join(img_dir2,row['filename'])
        print(data_path)
        img = cv2.imread(data_path)
        img = cv2.resize(img,(256,256))  
        non_covid.append(img)
# Out:
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\ARDSSevere.png
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\SARS-10.1148rg.242035193-g04mr34g0-Fig8a-day0.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\SARS-10.1148rg.242035193-g04mr34g0-Fig8b-day5.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\SARS-10.1148rg.242035193-g04mr34g0-Fig8c-day10.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\SARS-10.1148rg.242035193-g04mr34g04a-Fig4a-day7.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\SARS-10.1148rg.242035193-g04mr34g04b-Fig4b-day12.jpeg
# F:\study\corona\covid-chestxray-dataset-master\covid-chestxray-dataset-master\images\SARS-10.1148rg.242035193-g04mr34g05x-Fig5-day9.jpeg
# ...

# %%
data_generator = ImageDataGenerator(rotation_range = 10,width_shift_range = 0.1,height_shift_range = 0.1,shear_range = 0.1, zoom_range = 0.1, horizontal_flip = True, fill_mode = 'nearest')

# %%
noncov_aug = []
for j in range(len(non_covid)):
    datat_1 = img_to_array(non_covid[j])
    datat_1 = datat_1.reshape((1,)+datat_1.shape)
    i = 0
    for batch in data_generator.flow(datat_1):
        noncov_aug.append(np.array(array_to_img(batch[0])))
        i+=1
        if i == 2:
            break

# %%
noncov_aug[0].shape
# Out:
# (256, 256, 3)

# %%
trainn = normal + covid + noncov_aug

# %%
label_n = [0 for i in range(len(normal))]
label_c = [1 for i in range(len(covid))]
label_nc = [2 for i in range(len(noncov_aug))]

# %%
labels = label_n+label_c+label_nc

# %%
labels=np.array(labels)

# %%
labels.shape
# Out:
# (210,)

# %%
from keras.utils import to_categorical
la=to_categorical(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(trainn, la, test_size=0.20, random_state=42)

# %%
X_train[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## model 1

# %%
from keras.applications import resnet50
from keras.models import Model
import keras

res = resnet50.ResNet50(include_top=False, weights='imagenet',input_shape=(256,256,3),pooling=max)

res.trainable = False
for layer in res.layers:
    layer.trainable = False
    
flat=keras.layers.Flatten()(res.output)
#dense1=keras.layers.Dense(256,activation='linear')(flat)
output=keras.layers.Dense(3,activation='softmax')(flat)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\keras_applications\resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# ...
# 94658560/94653016 [==============================] - 37s 0us/step

# %%
model=Model(input=res.input,output=output)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   """Entry point for launching an IPython kernel.

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 128, 128, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 64) 0           bn_conv1[0][0]
# ...

# %%
#from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions

model_2 = resnet50.ResNet50(include_top=False,weights='imagenet',input_shape = (256,256,3))

model_2.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 262, 262, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 128, 128, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 128, 128, 64) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 128, 128, 64) 0           bn_conv1[0][0]
# ...

# %%
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
fit=model.fit(np.array(X_train),np.array(y_train),epochs=5,verbose=1,validation_data=(np.array(X_test), np.array(y_test)))
# Out:
# Train on 168 samples, validate on 42 samples
# Epoch 1/5
# 168/168 [==============================] - 94s 560ms/step - loss: 3.5531 - accuracy: 0.6310 - val_loss: 2.8375 - val_accuracy: 0.6429
# Epoch 2/5
# 168/168 [==============================] - 79s 473ms/step - loss: 1.0622 - accuracy: 0.9226 - val_loss: 1.7358 - val_accuracy: 0.7619
# Epoch 3/5
# 168/168 [==============================] - 82s 490ms/step - loss: 0.4278 - accuracy: 0.9821 - val_loss: 6.1214 - val_accuracy: 0.6429
# Epoch 4/5
# 168/168 [==============================] - 83s 495ms/step - loss: 0.6938 - accuracy: 0.9643 - val_loss: 2.9452 - val_accuracy: 0.7857
# Epoch 5/5
# 168/168 [==============================] - 80s 476ms/step - loss: 1.4192e-09 - accuracy: 1.0000 - val_loss: 1.6381 - val_accuracy: 0.8571

# %%
trainn[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# ## Model 2

# %%
from keras.applications import vgg16
from keras.models import Model
import keras

vgg = vgg16.VGG16(include_top=False, weights='imagenet',input_shape=(256,256,3),pooling=max)

vgg.trainable = False
for layer in vgg.layers:
    layer.trainable = False
    
flat=keras.layers.Flatten()(vgg.output)
#dense1=keras.layers.Dense(256,activation='linear')(flat)
output=keras.layers.Dense(3,activation='softmax')(flat)
# Out:
# ...
# 58892288/58889256 [==============================] - 93s 2us/step

# %%
model_3=Model(input=vgg.input,output=output)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("de...)`
#   """Entry point for launching an IPython kernel.

# %%
model_3.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_3 (InputLayer)         (None, 256, 256, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# ...

# %%
model_3.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
fit_3=model_3.fit(np.array(X_train),np.array(y_train),epochs=5,verbose=1,validation_data=(np.array(X_test), np.array(y_test)))
# Out:
# Train on 168 samples, validate on 42 samples
# Epoch 1/5
# 168/168 [==============================] - 99s 592ms/step - loss: 11.0860 - accuracy: 0.5298 - val_loss: 2.1702 - val_accuracy: 0.7857
# Epoch 2/5
# 168/168 [==============================] - 106s 629ms/step - loss: 2.5930 - accuracy: 0.8988 - val_loss: 6.5843 - val_accuracy: 0.7143
# Epoch 3/5
# 168/168 [==============================] - 107s 637ms/step - loss: 0.3385 - accuracy: 0.9821 - val_loss: 3.2519 - val_accuracy: 0.9048
# Epoch 4/5
# 168/168 [==============================] - 110s 652ms/step - loss: 0.5563 - accuracy: 0.9643 - val_loss: 3.3306 - val_accuracy: 0.8810
# Epoch 5/5
# 168/168 [==============================] - 108s 642ms/step - loss: 3.6199e-06 - accuracy: 1.0000 - val_loss: 2.4975 - val_accuracy: 0.9048

# %% [markdown]
# ## Model_3

# %%
model_4 = keras.models.Sequential()

# %%
model_4.add(keras.layers.Conv2D(32,(3,3),activation = 'relu',input_shape = (256,256,3)))

# %%
model_4.add(keras.layers.AveragePooling2D(2,2))

# %%
model_4.add(keras.layers.Dropout(0.2))

# %%
model_4.add(keras.layers.Conv2D(32,(3,3),activation = 'relu'))

# %%
model_4.add(keras.layers.AveragePooling2D(2,2))

# %%
model_4.add(keras.layers.Flatten())

# %%
model_4.add(keras.layers.Dense(64,activation = 'relu'))

# %%
model_4.add(keras.layers.Dense(3,activation = 'softmax'))

# %%
model_4.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 254, 254, 32)      896
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 127, 127, 32)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 125, 125, 32)      9248
# _________________________________________________________________
# average_pooling2d_2 (Average (None, 62, 62, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 123008)            0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                7872576
# ...

# %%
model_4.compile(loss='categorical_crossentropy',optimizer='Nadam',metrics=['accuracy'])

# %%
fit_3=model_4.fit(np.array(X_train),np.array(y_train),epochs=10,verbose=1,validation_data=(np.array(X_test), np.array(y_test)))
# Out:
# Train on 168 samples, validate on 42 samples
# Epoch 1/10
# 168/168 [==============================] - 8s 47ms/step - loss: 1838.3794 - accuracy: 0.4107 - val_loss: 15.2265 - val_accuracy: 0.5000
# Epoch 2/10
# 168/168 [==============================] - 6s 38ms/step - loss: 19.5428 - accuracy: 0.5714 - val_loss: 0.8416 - val_accuracy: 0.5952
# Epoch 3/10
# 168/168 [==============================] - 6s 37ms/step - loss: 5.7659 - accuracy: 0.4762 - val_loss: 0.9664 - val_accuracy: 0.5476
# Epoch 4/10
# 168/168 [==============================] - 6s 37ms/step - loss: 0.4675 - accuracy: 0.8036 - val_loss: 0.9823 - val_accuracy: 0.5952
# Epoch 5/10
# 168/168 [==============================] - 6s 36ms/step - loss: 0.4904 - accuracy: 0.7560 - val_loss: 1.0405 - val_accuracy: 0.5714
# Epoch 6/10
# 168/168 [==============================] - 6s 37ms/step - loss: 0.4867 - accuracy: 0.8393 - val_loss: 1.1993 - val_accuracy: 0.5952
# Epoch 7/10
# ...
